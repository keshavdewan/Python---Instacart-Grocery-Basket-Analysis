# %% [markdown]
# # Importing Data

# %%
import pandas as pd
import numpy as np
import os

# %%
# Define function
def add_num(x,y):
    sum = x+y
    return sum

# %%
# Run function
add_num(9,11)
# Out:
# 20

# %%
df_ords_products_merged_path = r'C:\Users\iNDIA\Desktop\Career Foundry\4 Python Fundamentals for Data Analysts\Instacart Basket Analysis Mar 22\02 Data\Prepared Data\orders_products_merged.pkl'

# %%
# Importing ords_prods_merged 
df_ords_products_merged = pd.read_pickle(os.path.join(df_ords_products_merged_path))

# %%
# creating table subset
df = df_ords_products_merged[:1000000]

# %%
df.shape
# Out:
# (1000000, 17)

# %%
# creating functions

def price_label(row):
    if row['prices'] <= 5:
        return 'Low-range product'
    elif (row['prices'] > 5) and (row['prices'] <= 15):
        return 'Mid-range product'
    elif row['prices'] > 15:
        return 'High range'
    else: return 'Not enough data'

# %%
df['price_range'] = df.apply(price_label, axis =1)
# Out:
# C:\Users\iNDIA\AppData\Local\Temp/ipykernel_13120/2067299264.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis =1)

# %%
df['price_range'].value_counts(dropna= False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
df['prices'].max()
# Out:
# 14.8

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\iNDIA\anaconda3\lib\site-packages\pandas\core\indexing.py:1684: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# C:\Users\iNDIA\anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <=5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range_loc, dtype: int64

# %%
# Using loc on df_ords_products_merged

# %%
df_ords_products_merged.loc[df_ords_products_merged['prices'] >15, 'price_range_loc'] = 'High-end product'

# %%
df_ords_products_merged.loc[(df_ords_products_merged['prices'] <= 15) & (df_ords_products_merged['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_ords_products_merged.loc[df_ords_products_merged['prices'] <=5, 'price_range_loc'] = 'Low-range product'

# %%
df_ords_products_merged['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product    21861997
# Low-range product    10126366
# High-end product       417678
# Name: price_range_loc, dtype: int64

# %% [markdown]
# # IF- Statements with For-Loops

# %%
for x in range(30,45):
    print('My age is %d' % (x))
# Out:
# My age is 30
# My age is 31
# My age is 32
# My age is 33
# My age is 34
# My age is 35
# My age is 36
# My age is 37
# My age is 38
# My age is 39
# My age is 40
# My age is 41
# My age is 42
# My age is 43
# My age is 44

# %%
# on which day most orders take place
df_ords_products_merged['order_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6204404
# 1    5660456
# 6    4496635
# 2    4213986
# 5    4205906
# 3    3840701
# 4    3783953
# Name: order_day_of_week, dtype: int64

# %%
result = []

for value in df_ords_products_merged['order_day_of_week']:
    if value == 0:
        result.append('Busiest day')
    elif value == 4:
        result.append('Least busy')
    else:
        result.append('Regularly busy')

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
df_ords_products_merged['busiest_day'] = result

# %%
df_ords_products_merged['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    22417684
# Busiest day        6204404
# Least busy         3783953
# Name: busiest_day, dtype: int64

# %% [markdown]
# # TASK

# %%
# Q2.  the two busiest & slowest days. Create a new column for this using a suitable method.
df_ords_products_merged['order_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6204404
# 1    5660456
# 6    4496635
# 2    4213986
# 5    4205906
# 3    3840701
# 4    3783953
# Name: order_day_of_week, dtype: int64

# %%
result = []

for value in df_ords_products_merged['order_day_of_week']:
    if value == 1:
        result.append('Busiest Days')
    elif value == 0:
        result.append('Busiest Days')
    elif value == 4:
        result.append('Slowest Days')
    elif value == 3:
        result.append('Slowest Days')
    else:
        result.append('Regularly busy')

# %%
result
# Out:
# ['Regularly busy',
#  'Slowest Days',
#  'Slowest Days',
#  'Slowest Days',
#  'Slowest Days',
#  'Regularly busy',
#  'Busiest Days',
#  'Busiest Days',
#  'Busiest Days',
#  'Slowest Days',
#  'Busiest Days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest Days',
#  'Busiest Days',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest Days',
#  'Slowest Days',
#  'Slowest Days',
#  'Slowest Days',
#  'Slowest Days',
#  'Slowest Days',
#  'Busiest Days',
#  'Busiest Days',
#  'Busiest Days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest Days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest Days',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest Days',
#  'Regularly busy',
#  'Slowest Days',
#  'Busiest Days',
#  'Busiest Days',
#  'Regularly busy',
#  'Slowest Days',
#  'Slowest Days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest Days',
#  'Busiest Days',
#  'Regularly busy',
#  'Busiest Days',
#  'Busiest Days',
# ...

# %%
df_ords_products_merged['busiest_days'] = result

# %%
df_ords_products_merged['busiest_days'].value_counts(dropna = False)
# Out:
# Regularly busy    12916527
# Busiest Days      11864860
# Slowest Days       7624654
# Name: busiest_days, dtype: int64

# %% [markdown]
# ### Reduction in the regularly busy days and an increase in busiest and slowest days

# %%
df_ords_products_merged.describe()
# Out:
#            order_id       user_id  order_number  order_day_of_week  \
# count  3.240604e+07  3.240604e+07  3.240604e+07       3.240604e+07
# mean   1.710745e+06  1.029371e+05  1.714223e+01       2.738862e+00
# std    9.872986e+05  5.946610e+04  1.753527e+01       2.090074e+00
# min    2.000000e+00  1.000000e+00  1.000000e+00       0.000000e+00
# 25%    8.559480e+05  5.142200e+04  5.000000e+00       1.000000e+00
# 50%    1.711050e+06  1.026150e+05  1.100000e+01       3.000000e+00
# 75%    2.565497e+06  1.543880e+05  2.400000e+01       5.000000e+00
# max    3.421083e+06  2.062090e+05  9.900000e+01       6.000000e+00
#
#          order_time  days_since_prior_order    product_id  add_to_cart_order  \
# count  3.240604e+07            3.032984e+07  3.240604e+07       3.240604e+07
# mean   1.342515e+01            1.110410e+01  2.559895e+04       8.352616e+00
# std    4.246382e+00            8.779062e+00  1.408389e+04       7.127128e+00
# ...

# %%
# Q4. The busiest hours of the day. Rather than by hour, they want periods of time labeled “Most orders,” “Average orders,” and “Fewest orders.” Create a new column containing these labels called “busiest_period_of_day.”

# %%
df_ords_products_merged['order_time'].value_counts(dropna = False)
# Out:
# 10    2761862
# 11    2736242
# 14    2689251
# 15    2662246
# 13    2661057
# 12    2618613
# 16    2535313
# 9     2454273
# 17    2087721
# 8     1718182
# 18    1636566
# 19    1258352
# 20     976182
# 7      891082
# 21     795658
# 22     634247
# 23     402335
# 6      290500
# 0      218786
# 1      115706
# 5       87964
# 2       69377
# 4       53245
# 3       51281
# Name: order_time, dtype: int64

# %%
result_2 = []

for value in df_ords_products_merged['order_time']:
    if value >= 9 and value <17:
        result_2.append('Most Orders')
    elif value <= 6:
        result_2.append('Fewest Orders')
    else:
        result_2.append('Avergae Orders')

# %%
result_2
# Out:
# ['Avergae Orders',
#  'Avergae Orders',
#  'Most Orders',
#  'Avergae Orders',
#  'Most Orders',
#  'Avergae Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Avergae Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Avergae Orders',
#  'Most Orders',
#  'Avergae Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Avergae Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Avergae Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
# ...

# %%
df_ords_products_merged['busiest_period_of_day'] = result_2

# %%
# Q5. Frequency of Column
df_ords_products_merged['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Most Orders       21118857
# Avergae Orders    10400325
# Fewest Orders       886859
# Name: busiest_period_of_day, dtype: int64

# %%
df_ords_products_merged.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_time  \
# 0   2539329        1             1                  2           8
# 1   2398795        1             2                  3           7
# 2    473747        1             3                  3          12
# 3   2254736        1             4                  4           7
# 4    431534        1             5                  4          15
#
#    days_since_prior_order  first_time_customer  product_id  add_to_cart_order  \
# 0                     NaN                 True         196                  1
# 1                    15.0                False         196                  1
# 2                    21.0                False         196                  1
# 3                    29.0                False         196                  1
# 4                    28.0                False         196                  1
#
#    reordered  ... Unnamed: 0  product_name aisle_id  department_id  prices  \
# ...

# %%
df_ords_products_merged_path = r'C:\Users\iNDIA\Desktop\Career Foundry\4 Python Fundamentals for Data Analysts\Instacart Basket Analysis Mar 22\02 Data\Prepared Data\orders_products_merged.csv'

# %%
# Q7. Export your dataframe as a pickle file (since you added new columns) and store it correctly in your “Prepared Data” folder.
df_ords_products_merged.to_pickle(os.path.join(df_ords_products_merged_path))

# %%
df_ords_products_merged.isnull().sum()
# Out:
# order_id                        0
# user_id                         0
# order_number                    0
# order_day_of_week               0
# order_time                      0
# days_since_prior_order    2076201
# first_time_customer             0
# product_id                      0
# add_to_cart_order               0
# reordered                       0
# _merge                          0
# Unnamed: 0                      0
# product_name                    0
# aisle_id                        0
# department_id                   0
# prices                          0
# True                            0
# price_range_loc                 0
# busiest_day                     0
# busiest_days                    0
# busiest_period_of_day           0
# dtype: int64
