# %% [markdown]
# # Importing Data

# %%
import pandas as pd
import numpy as np
import os

# %%
# Q3. Importing orders_products_combined

df_orders_products_combined = pd.read_pickle(r'C:\Users\iNDIA\Desktop\Career Foundry\4 Python Fundamentals for Data Analysts\Instacart Basket Analysis Mar 22\02 Data\Prepared Data\orders_products_combined.pkl')

# %%
# Q4. Shape of imported dataframe
df_orders_products_combined.shape
# Out:
# (32434489, 11)

# %%
df_orders_products_combined.isnull().sum()
# Out:
# order_id                        0
# user_id                         0
# order_number                    0
# order_day_of_week               0
# order_time                      0
# days_since_prior_order    2078068
# first_time_customer             0
# product_id                      0
# add_to_cart_order               0
# reordered                       0
# _merge                          0
# dtype: int64

# %%
df_orders_products_combined.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_time  \
# 0   2539329        1             1                  2           8
# 1   2539329        1             1                  2           8
# 2   2539329        1             1                  2           8
# 3   2539329        1             1                  2           8
# 4   2539329        1             1                  2           8
#
#    days_since_prior_order  first_time_customer  product_id  add_to_cart_order  \
# 0                     NaN                 True         196                  1
# 1                     NaN                 True       14084                  2
# 2                     NaN                 True       12427                  3
# 3                     NaN                 True       26088                  4
# 4                     NaN                 True       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# ...

# %%
# Q5. Importing Product Data Set

df_products_checked = pd.read_csv(r'C:\Users\iNDIA\Desktop\Career Foundry\4 Python Fundamentals for Data Analysts\Instacart Basket Analysis Mar 22\02 Data\Prepared Data\products_checked.csv')

# %%
df_products_checked.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
df_products_checked.isnull().sum()
# Out:
# Unnamed: 0       0
# product_id       0
# product_name     0
# aisle_id         0
# department_id    0
# prices           0
# dtype: int64

# %%
# dropping useless column 'unnamed: 0'

df_products_checked.drop(columns = ['Unnamed: 0'])
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49672       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49673       49685                 En Croute Roast Hazelnut Cranberry
# 49674       49686                                   Artisan Baguette
# 49675       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49676       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
# dropping useless column '_merge'

df_orders_products_combined.drop(columns = ['_merge'])
# Out:
#           order_id  user_id  order_number  order_day_of_week  order_time  \
# 0          2539329        1             1                  2           8
# 1          2539329        1             1                  2           8
# 2          2539329        1             1                  2           8
# 3          2539329        1             1                  2           8
# 4          2539329        1             1                  2           8
# ...            ...      ...           ...                ...         ...
# 32434484   2977660   206209            13                  1          12
# 32434485   2977660   206209            13                  1          12
# 32434486   2977660   206209            13                  1          12
# 32434487   2977660   206209            13                  1          12
# 32434488   2977660   206209            13                  1          12
#
#           days_since_prior_order  first_time_customer  product_id  \
# ...

# %%
# Merging Columns

df_orders_products_combined_merged = df_orders_products_combined.merge(df_products_checked, on = ['product_id'], indicator = 'True')

# %%
df_orders_products_combined_merged.isnull().sum()
# Out:
# order_id                        0
# user_id                         0
# order_number                    0
# order_day_of_week               0
# order_time                      0
# days_since_prior_order    2076201
# first_time_customer             0
# product_id                      0
# add_to_cart_order               0
# reordered                       0
# _merge                          0
# Unnamed: 0                      0
# product_name                    0
# aisle_id                        0
# department_id                   0
# prices                          0
# True                            0
# dtype: int64

# %%
df_orders_products_combined_merged.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_time  \
# 0   2539329        1             1                  2           8
# 1   2398795        1             2                  3           7
# 2    473747        1             3                  3          12
# 3   2254736        1             4                  4           7
# 4    431534        1             5                  4          15
#
#    days_since_prior_order  first_time_customer  product_id  add_to_cart_order  \
# 0                     NaN                 True         196                  1
# 1                    15.0                False         196                  1
# 2                    21.0                False         196                  1
# 3                    29.0                False         196                  1
# 4                    28.0                False         196                  1
#
#    reordered _merge  Unnamed: 0 product_name  aisle_id  department_id  prices  \
# ...

# %%
# Q6.Confirm the results of the merge using the merge flag.
df_orders_products_combined_merged['_merge'].value_counts()
# Out:
# both          32406041
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
orders_products_merged_path=r'C:\Users\iNDIA\Desktop\Career Foundry\4 Python Fundamentals for Data Analysts\Instacart Basket Analysis Mar 22\02 Data\Prepared Data'

# %%
# Q7. Export the newly created dataframe as orders_products_merged in a suitable format
df_orders_products_combined_merged.to_pickle(os.path.join(orders_products_merged_path, 'orders_products_merged.pkl'))

# %%
df_orders_products_combined_merged.to_csv(os.path.join(orders_products_merged_path, 'orders_products_merged.csv'))
